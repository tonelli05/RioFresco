# %%
import pandas as pd

# %% [markdown]
# ## Limpeza de Dados

# %%
saude = pd.read_csv('dados/taxas_internacoesRJ_23-25.csv', sep = ';', encoding = 'latin1', decimal = ',')

# %%
colunas_novas = {
    'Município': 'municipio',
    'Taxa de internação': 'taxa_internacao_geral',
    'Taxa de internação p/infecções respiratórias agudas': 'taxa_respiratoria',
    'Taxa de internação p/pneumonia': 'taxa_pneumonia',
    'Taxa de internação p/doenças aparelho circulatório': 'taxa_circulatorio'
}

saude = saude.rename(columns = colunas_novas)

# %% [markdown]
# ## Exportacao do dataset limpo

# %%
saude.to_csv('dados/saude_limpo.csv', index = False, encoding = 'utf-8')
